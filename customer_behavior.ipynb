# %%
import pandas as pd

# %%
df=pd.read_csv("shopping_customer_data.csv")

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   22  Female            Bag  Footwear                    484
# 1            2   58  Female          Shirt  Footwear                    105
# 2            3   52  Female          Watch  Footwear                    324
# 3            4   40    Male          Jeans  Footwear                    404
# 4            5   40  Female          Watch  Clothing                    441
#
#   Location Size  Color  Season  Review Rating Subscription Status  \
# 0    Delhi   XL    Red  Summer            2.6                  No
# 1  Lucknow    M  White  Summer            1.5                 Yes
# 2  Lucknow    L   Blue  Autumn            2.5                 Yes
# 3  Lucknow   XL   Blue  Spring            2.6                 Yes
# 4   Mumbai   XL  Black  Winter            1.4                  No
#
#   Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0       Express               No             Yes                   5
# 1       Express              Yes             Yes                  17
# 2      Next Day               No              No                  13
# 3      Next Day              Yes              No                  24
# 4       Express               No              No                  15
#
#   Payment Method Frequency of Purchases
# 0    Net Banking                 Weekly
# 1    Net Banking                Monthly
# 2    Net Banking                 Weekly
# 3           Card              Quarterly
# 4           Card              Quarterly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 548.6+ KB

# %%
df.describe(include=
           'all')
# Out:
#         Customer ID          Age Gender Item Purchased     Category  \
# count   3900.000000  3900.000000   3900           3900         3900
# unique          NaN          NaN      2              5            3
# top             NaN          NaN   Male          Watch  Accessories
# freq            NaN          NaN   1986            806         1352
# mean    1950.500000    43.522051    NaN            NaN          NaN
# std     1125.977353    15.009453    NaN            NaN          NaN
# min        1.000000    18.000000    NaN            NaN          NaN
# 25%      975.750000    30.000000    NaN            NaN          NaN
# 50%     1950.500000    43.000000    NaN            NaN          NaN
# 75%     2925.250000    57.000000    NaN            NaN          NaN
# max     3900.000000    69.000000    NaN            NaN          NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# unique                    NaN        4     4      4       4            NaN
# top                       NaN  Lucknow     S  White  Autumn            NaN
# freq                      NaN      981  1018   1026     995            NaN
# mean               253.020513      NaN   NaN    NaN     NaN       3.033963
# std                142.625920      NaN   NaN    NaN     NaN       1.164091
# min                 10.000000      NaN   NaN    NaN     NaN       1.000000
# 25%                128.000000      NaN   NaN    NaN     NaN       2.000000
# 50%                253.000000      NaN   NaN    NaN     NaN       3.100000
# 75%                375.000000      NaN   NaN    NaN     NaN       4.100000
# max                499.000000      NaN   NaN    NaN     NaN       5.000000
#
#        Subscription Status Shipping Type Discount Applied Promo Code Used  \
# count                 3900          3900             3900            3900
# unique                   2             3                2               2
# top                    Yes      Standard              Yes             Yes
# freq                  1978          1322             1975            1958
# mean                   NaN           NaN              NaN             NaN
# std                    NaN           NaN              NaN             NaN
# min                    NaN           NaN              NaN             NaN
# 25%                    NaN           NaN              NaN             NaN
# 50%                    NaN           NaN              NaN             NaN
# 75%                    NaN           NaN              NaN             NaN
# max                    NaN           NaN              NaN             NaN
#
#         Previous Purchases Payment Method Frequency of Purchases
# count          3900.000000           3900                   3900
# unique                 NaN              4                      3
# top                    NaN           Card                 Weekly
# freq                   NaN           1021                   1327
# mean             24.876667            NaN                    NaN
# std              14.488028            NaN                    NaN
# min               0.000000            NaN                    NaN
# 25%              12.000000            NaN                    NaN
# 50%              25.000000            NaN                    NaN
# 75%              37.000000            NaN                    NaN
# max              49.000000            NaN                    NaN

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Review Rating']=df.groupby('Category')['Review Rating'].transform(lambda x:x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')

df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
labels=['young_adult','adult','middle_age','senior']
df['age_group']=pd.qcut(df['age'],q=4,labels=labels)

# %%
df[['age','age_group']].head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df[['age','age_group']].head(5)
#
# NameError: name 'df' is not defined

# %%
# Create column purchase_frequency_days

frequency_mapping = {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 13
#       1 # Create column purchase_frequency_days
#       3 frequency_mapping = {
#       4     'Fortnightly': 14,
#       5     'Weekly': 7,
#    (...)     10     'Every 3 Months': 90
#      11 }
# ---> 13 df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)
#
# NameError: name 'df' is not defined

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df[['purchase_frequency_days','frequency_of_purchases']].head(15)
#
# NameError: name 'df' is not defined

# %%
(df['promo_code_used']==df['discount_applied']).all()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 (df['promo_code_used']==df['discount_applied']).all()
#
# NameError: name 'df' is not defined

# %%
# !pip install psycopg2-binary sqlalchemy
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\vs\anaconda3\lib\site-packages (2.9.12)
# Requirement already satisfied: sqlalchemy in c:\users\vs\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: greenlet>=1 in c:\users\vs\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\vs\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)

# %%
from sqlalchemy import create_engine

username = "postgres"
password = "newpassword123"
host = "localhost"
port = "5432"
database = "customer_behavior"

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

table_name = "customer"

df.to_sql(
    table_name,
    engine,
    if_exists="replace",
    index=False
)

print(
    f"Data successfully loaded into table '{table_name}' in database '{database}'."
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 15
#       9 engine = create_engine(
#      10     f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
#      11 )
#      13 table_name = "customer"
# ---> 15 df.to_sql(
#      16     table_name,
#      17     engine,
#      18     if_exists="replace",
#      19     index=False
#      20 )
#      22 print(
#      23     f"Data successfully loaded into table '{table_name}' in database '{database}'."
#      24 )
#
# NameError: name 'df' is not defined

# %%
from sqlalchemy import create_engine

username = "postgres"
password = "newpassword123"
host = "localhost"
port = "5432"
database = "customer_behavior"

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

table_name = "customer"

df.to_sql(
    table_name,
    engine,
    if_exists="replace",
    index=False
)

print(
    f"Data successfully loaded into table '{table_name}' in database '{database}'."
)
